# %% [markdown]
# # Text Quality Analyzer
# by Ricky | v1(20/04/2020)

# %% [markdown]
# ## Observations
#
# Are interpreted as wrong words:
# - URLs
# - alphanumeric codes (ej: dsa543nqhf7dh3ndsaku43878)
#
# Are interpreted as correct words:
# - fem words
# - plural words
# - verb conjugations
# - words accompanied by symbols or punctuation at the beginning or end (ex: "example:")
#
# Are omited:
# - All the expresiond than contains only numbers and symbols (ex: 19/04/2020, 12.345.678-9)
#
#
# ## Possible Improvements:
#
# - Save all the wrong words to analyze if they really are wrong words or are technisisms, abbreviations or terms of the company culture.
#
# - Detect the leanguaje of the text (so not all words of the texts are selected as wrong words)

# %% [markdown]
# ## Initial Load

# %% [markdown]
# ### Imports

# %%
from os import listdir
import pandas as pd
import boto3

from io import BytesIO
from functools import reduce
from os.path import join as pjoin
from datetime import datetime as dt

# %% [markdown]
# ### Variables

# %%
# Sybols to delete before and after the word:
NOT_ALLOWED = ' \n.,-:;?¿\'"'
NOT_ALLOWED_REGEX = r'\n\.,\-:;?¿\'"'

DIRECTORY_DICTS = 'languages_dictionaries'
SPANISH_DICT = 'spanish.0'
ENGLISH_DICT = 'english.0'

# Bucket variables:
bucket = "kranio-datalake"
key = "internal/webinar/leoCamilo/raw/ratings.csv"
key2 = "internal/webinar/leoCamilo/raw/complaints.csv"

AWS_REGION = 'us-east-2'

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# ### Helpers

# %%
def file_to_words_list(file_path):
    '''
    Receives the path of a file. Each line of the file contains one word.
    Return a list with the words.
    '''
    with open(file_path, 'r', encoding='utf-8') as file_obj:
        return words_list_from(file_obj.readlines())

def words_list_from(file_obj):
    return list(map(lambda word: word.strip().lower(), file_obj))

def files_to_lists(directory, *files):
    '''
    Receives a directory. If file names are given, those will be processed.
    Otherwise all the files in the directory will be processed.
    Return a list of lists with words.
    '''
    if files: lst_files = files # specified files are processed
    else: lst_files = listdir(directory) # all files in directory are processed
    return list(map(lambda x: file_to_words_list(pjoin(directory, x)), lst_files))

# %%
def has_alpha_char(word):
    '''
    If word contains alphabet characters returns True. False otherwise.
    '''
    if word: return reduce(lambda a,b: a or b, map(lambda x: x.isalpha(), word))

class TextMetrics():
    def __init__(self, total_words, wrong_words, quality_score):
        self.total_words = total_words
        self.wrong_words = wrong_words
        self.quality_score = quality_score

class TextQualityAnalyzer:
    def __init__(self, *words_lists):
        self.idiom_words = reduce(lambda lst1, lst2: lst1 + lst2, words_lists)
        self.text = ''
        self.__iter_words = None
    
    def __parse_text(self):
         self.__iter_words = map(lambda word: word.strip(NOT_ALLOWED), self.text.split(' '))
    
    def word_exist(self, word):
        '''
        If the word exist in the word list return True. False otherwise.
        '''
        word = word.lower()
        return word in self.idiom_words
        
    def __check_words_existance(self):
        wrong_words = 0
        total_words = 0
        for word in self.__iter_words:
            if has_alpha_char(word):
                wrong_words += int(not self.word_exist(word))
                total_words += 1
        return total_words, wrong_words
            
    def generate_metrics_obj(self, text):
        '''
        Receives a text and return an object with its metrics and score(int) depending of the existing words.
        '''      
        self.text = text
        self.__parse_text()
        total_words, wrong_words = self.__check_words_existance()
        quality_score = total_words // (wrong_words + 1)
        return TextMetrics(total_words, wrong_words, quality_score)

# %% [markdown]
# ### TextQualityAnalyzer Object Creation

# %%
lst_words = file_to_words_list(pjoin(DIRECTORY_DICTS, ENGLISH_DICT)) # Change here the language
tqa = TextQualityAnalyzer(lst_words) # Here you can add all lists you want separated by ','

# %%
lst_words
# Out:
# ['W',
#  'w',
#  'WW',
#  'WWW',
#  'WY',
#  'Y',
#  'y',
#  'A',
#  'a',
#  'AA',
#  'AAA',
#  'aah',
#  'ah',
#  'AI',
#  'air',
#  'AR',
#  'Ar',
#  'Au',
#  'aw',
#  'E',
#  'e',
#  'ea',
#  'ear',
#  'EEO',
#  "e'er",
#  'eh',
#  'EOE',
#  'ER',
#  'Er',
#  'EU',
#  'Eu',
#  'Eur',
#  'I',
#  'i',
#  'IA',
#  'Ia',
#  'IE',
#  'ii',
#  'iii',
#  'Io',
#  'IOU',
#  'Ir',
#  'O',
#  'o',
#  'oar',
#  'OE',
#  "o'er",
#  'OH',
#  'oh',
#  'oi',
#  'ooh',
#  'OR',
#  'or',
#  'our',
#  'ow',
#  'U',
#  'u',
#  'UAR',
#  'UAW',
#  'ugh',
#  'uh',
#  'Ur',
#  'aether',
#  'Arther',
#  'Arthur',
#  'Aurthur',
#  'author',
#  'earth',
#  'Eartha',
#  'earthier',
#  'earthy',
#  'eighth',
#  'either',
#  'Ertha',
#  'Ethe',
#  'ether',
#  'oath',
#  'Otha',
#  'other',
#  'Otho',
#  'earthbound',
#  'Athabasca',
#  'Athabaskan',
#  "Athabascan's",
#  "Athabaskan's",
#  'Athabaskans',
#  "Athabasca's",
#  "Athabaska's",
#  'orthorhombic',
#  'ethic',
#  'Ithaca',
#  'earthquake',
#  'earthquaking',
#  "earthquake's",
#  'earthquakes',
#  'earthquaked',
#  'ethical',
#  'ethically',
#  'ethicals',
#  'Ithacan',
#  'orthogonal',
#  'orthogonally',
#  'orthogonality',
#  "orthogonality's",
#  'orthography',
#  'orthographic',
#  'orthographical',
#  'orthographically',
#  'orthographies',
#  "orthography's",
#  "ethic's",
#  'ethics',
#  "Ithaca's",
#  'earthlier',
#  'earthly',
#  'Ethel',
#  'Ethyl',
#  'ethyl',
#  'Othelia',
#  'Othella',
#  'Othello',
#  'Othilia',
#  'Othilie',
#  'Ethelbert',
#  "Ethelbert's",
#  'ethology',
#  'ethological',
#  "ethology's",
#  'ethologist',
#  "ethologist's",
#  'ethologists',
#  'earthling',
#  'Ethelin',
#  'Etheline',
#  'Ethelyn',
#  'ethylene',
#  "earthling's",
#  'earthlings',
#  "Etheline's",
#  "Ethelin's",
#  "Ethelyn's",
#  "ethylene's",
#  'Ethelind',
#  "Ethelind's",
#  'Ethelred',
#  "Ethelred's",
#  "Ethel's",
#  "Ethyl's",
#  "ethyl's",
#  "Othelia's",
#  "Othella's",
#  "Othello's",
#  "Othilia's",
#  "Othilie's",
#  'earthliest',
#  'athlete',
#  'Ethelda',
#  'athletic',
#  'athletically',
#  'athletics',
#  "athletics's",
#  "athlete's",
#  'athletes',
#  "Ethelda's",
#  'athleticism',
#  "athleticism's",
#  'Athena',
#  'Athene',
#  'earthen',
#  'earthing',
#  'Ethan',
#  'ethane',
#  'ethnic',
#  'ethnically',
#  'ethnographer',
#  'ethnography',
#  'ethnographic',
#  'ethnographically',
#  "ethnographer's",
#  'ethnographers',
#  "ethnography's",
#  'ethnics',
#  'euthenics',
#  "euthenics's",
#  'ethanol',
#  'ethnology',
#  'ethnological',
#  'ethnologically',
#  "ethnology's",
#  'ethnologist',
#  "ethnologist's",
#  'ethnologists',
#  "ethanol's",
#  'orthonormal',
#  'Athenian',
#  "Athenian's",
#  'Athenians',
#  "Athena's",
#  "Athene's",
#  'Athens',
#  "Athens's",
#  'earthiness',
#  "earthiness's",
#  "ethane's",
#  "Ethan's",
#  'euthanize',
#  'otherness',
#  "otherness's",
#  'euthanizing',
#  'ethnocentric',
#  'ethnocentrism',
#  "ethnocentrism's",
#  'euthanizes',
#  'ethnicity',
#  'euthanized',
#  "ethnicity's",
#  'Ethernet',
#  'authentic',
#  'authentically',
#  'authenticate',
#  'authenticator',
#  'authenticating',
#  'authenticates',
#  "authenticator's",
#  'authenticators',
#  'authenticated',
#  'authentication',
#  "authentication's",
#  'authentications',
#  'authenticity',
#  "authenticity's",
#  'earthenware',
#  "earthenware's",
#  'euthanasia',
#  "euthanasia's",
#  'Ethiopia',
#  'Ethiopian',
#  'Ethiopians',
#  "Ethiopia's",
#  'authorial',
#  'ethereal',
#  'ethereally',
#  'Arthurian',
#  'authoring',
#  'arthropod',
#  "arthropod's",
#  'arthropods',
#  'authoress',
#  'atherosclerosis',
#  "atherosclerosis's",
#  'arthroscope',
#  'arthroscopic',
#  'arthroscopes',
#  'authoresses',
#  'authored',
#  'authority',
#  'arthritic',
#  'arthritics',
#  'authoritarian',
#  'authoritarians',
#  'authoritarianism',
#  "authoritarianism's",
#  'arthritis',
#  "arthritis's",
#  'authorities',
#  "authority's",
#  'authoritative',
#  'authoritatively',
#  'authoritativeness',
#  "authoritativeness's",
#  "aether's",
#  "Arther's",
#  "Arthur's",
#  "Aurthur's",
#  "author's",
#  'authors',
#  "Eartha's",
#  "earth's",
#  'earths',
#  'eighths',
#  "Ertha's",
#  "ether's",
#  "Ethe's",
#  'ethos',
#  "ethos's",
#  "oath's",
#  'oaths',
#  "Otha's",
#  'others',
#  "Otho's",
#  'outhouse',
#  'atheism',
#  "atheism's",
#  "outhouse's",
#  'outhouses',
#  'ethicist',
#  'atheist',
#  'athirst',
#  'earthiest',
#  'atheistic',
#  'atheistically',
#  "atheist's",
#  'atheists',
#  'earthed',
#  'outhit',
#  'Orthodox',
#  'orthodox',
#  'orthodoxy',
#  'Orthodoxes',
#  'orthodoxes',
#  'orthodoxies',
#  "orthodoxy's",
#  'outhitting',
#  'orthodontic',
#  'orthodontics',
#  "orthodontics's",
#  'orthodontist',
#  "orthodontist's",
#  'orthodontists',
#  'orthodontia',
#  'outhits',
#  'earthwork',
#  "earthwork's",
#  'earthworks',
#  'otherworldly',
#  'earthworm',
#  "earthworm's",
#  'earthworms',
#  'otherwise',
#  'athwart',
#  'earthward',
#  'earthwards',
#  'earthshaking',
#  'authorship',
#  "authorship's",
#  'AB',
#  'Ab',
#  'ab',
#  'ABA',
#  'Abba',
#  'Abbe',
#  'Abbey',
#  'abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abe',
#  'Abeu',
#  'Abey',
#  'Abie',
#  'Aube',
#  'Eb',
#  'Eba',
#  'eBay',
#  'ebb',
#  'Ebba',
#  'Ibbie',
#  'Ibby',
#  'Ibo',
#  'OB',
#  'Ob',
#  'ob',
#  'obey',
#  'obi',
#  'Obie',
#  'oboe',
#  'Oby',
#  'orb',
#  'above',
#  'aboveboard',
#  'obverse',
#  'obvious',
#  'obfuscate',
#  'obfuscating',
#  'obfuscatory',
#  'obfuscates',
#  'obfuscated',
#  'obfuscation',
#  "obfuscation's",
#  'obfuscations',
#  'obviously',
#  'obviousness',
#  "obviousness's",
#  'obverses',
#  'abaft',
#  'arborvitae',
#  'obviate',
#  'obviating',
#  "arborvitae's",
#  'arborvitaes',
#  'obviates',
#  'obviated',
#  'obviation',
#  'abhor',
#  'abhorring',
#  'abhorrence',
#  "abhorrence's",
#  'abhorrent',
#  'abhorrently',
#  'abhorred',
#  'abhors',
#  'Eberhard',
#  "Eberhard's",
#  'aback',
#  'ABC',
#  'Abuja',
#  'airbag',
#  'obj',
#  'abject',
#  'object',
#  'objector',
#  'objurgate',
#  'objectify',
#  'objective',
#  'objectification',
#  'objectively',
#  'objectiveness',
#  "objectiveness's",
#  'objectifies',
#  'objectives',
#  'objectified',
#  'objectivity',
#  "objectivity's",
#  'objectifying',
#  'abjectly',
#  'objectless',
#  'abjecting',
#  'objecting',
#  'objurgating',
#  'abjectness',
#  "abjectness's",
#  'abjects',
#  "objector's",
#  'objectors',
#  "object's",
#  'objects',
#  'objurgates',
#  'abjected',
#  'objected',
#  'objurgated',
#  'abjection',
#  'objection',
#  'objurgation',
#  'objectionable',
#  'objectionably',
#  'objectionableness',
#  "objectionableness's",
#  "abjection's",
#  "objection's",
#  'objections',
#  "objurgation's",
#  'objurgations',
#  'Abagael',
#  'Abagail',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'orbicular',
#  'orbiculares',
#  "Abagael's",
#  "Abagail's",
#  "Abigael's",
#  "Abigail's",
#  "Abigale's",
#  'aubergine',
#  "aubergine's",
#  'aubergines',
#  'abjure',
#  'abjurer',
#  'abjuring',
#  "abjurer's",
#  'abjurers',
#  'abjures',
#  'abjured',
#  'abjuratory',
#  'abjuration',
#  "abjuration's",
#  'abjurations',
#  'abacus',
#  "abacus's",
#  "ABC's",
#  'airbags',
#  'ibex',
#  'abacuses',
#  'ibexes',
#  "ibex's",
#  'ubiquity',
#  'ubiquitous',
#  'ubiquitously',
#  'Abel',
#  'able',
#  'abler',
#  'ably',
#  'Ebola',
#  'oblivion',
#  "oblivion's",
#  'oblivious',
#  'obliviously',
#  'obliviousness',
#  "obliviousness's",
#  'oblige',
#  'oblique',
#  'obloquy',
#  'obliquely',
#  'obliging',
#  'obligingly',
#  'obliqueness',
#  'obliges',
#  'obliques',
#  "obloquy's",
#  'obbligato',
#  'obligate',
#  'obliged',
#  'obliqued',
#  'obliquity',
#  'obligating',
#  'obligatory',
#  'obligatorily',
#  'obbligatos',
#  'obligates',
#  "obliquity's",
#  'obligated',
#  'obligation',
#  "obligation's",
#  'obligations',
#  'abloom',
#  'abalone',
#  'Abilene',
#  'Oberlin',
#  'oblong',
#  'oblongs',
#  "abalone's",
#  'abalones',
#  "Abilene's",
#  'ebullience',
#  "Oberlin's",
#  "ebullience's",
#  'ebullient',
#  'ebulliently',
#  "Abel's",
#  'ablaze',
#  'ables',
#  'Iblis',
#  "Iblis's",
#  'obelisk',
#  "obelisk's",
#  'obelisks',
#  'Abelson',
#  "Abelson's",
#  'ablest',
#  'Abelard',
#  'ability',
#  'ablate',
#  'oblate',
#  'oubliette',
#  'ablative',
#  'ablatives',
#  'ablating',
#  'obliterate',
#  'obliterating',
#  'obliterates',
#  'obliterated',
#  'obliteration',
#  "obliteration's",
#  "Abelard's",
#  'abilities',
#  "ability's",
#  'ablates',
#  "oubliette's",
#  'oubliettes',
#  'ablated',
#  'abolish',
#  'ablation',
#  'ablution',
#  'abolishing',
#  'abolition',
#  'ebullition',
#  'oblation',
#  "ablation's",
#  'ablations',
#  "ablution's",
#  'ablutions',
#  "abolition's",
#  "ebullition's",
#  "oblation's",
#  'oblations',
#  'abolitionism',
#  "abolitionism's",
#  'abolitionist',
#  "abolitionist's",
#  'abolitionists',
#  'abolishes',
#  'abolished',
#  'abeam',
#  'ABM',
#  'erbium',
#  'IBM',
#  'abominable',
#  'abominably',
#  'abominate',
#  'abominating',
#  'abominates',
#  'abominated',
#  'abomination',
#  "abomination's",
#  'abominations',
#  'ABMs',
#  "erbium's",
#  "IBM's",
#  'Abner',
#  'airborne',
#  'Aubine',
#  'auburn',
#  'ebbing',
#  'Eben',
#  'Ebonee',
#  'Ebony',
#  'ebony',
#  'obiing',
#  'Urbain',
#  'Urban',
#  'urban',
#  'urbane',
#  'urbaner',
#  'Urbano',
#  'Abernathy',
#  "Abernathy's",
#  'Ubangi',
#  'Ebonics',
#  "Ubangi's",
#  'obnoxious',
#  'obnoxiously',
#  'obnoxiousness',
#  "obnoxiousness's",
#  'abnegate',
#  'abnegating',
#  'abnegates',
#  'abnegated',
#  'abnegation',
#  "abnegation's",
#  'urbanely',
#  'urbanology',
#  'urbanologist',
#  'urbanologists',
#  'abnormal',
#  'abnormally',
#  'abnormality',
#  'abnormalities',
#  "abnormality's",
#  'aborning',
#  "Abner's",
#  "Aubine's",
#  "auburn's",
#  'Ebeneezer',
#  'Ebeneser',
#  'Ebenezer',
#  "Eben's",
#  "Ebonee's",
#  'ebonies',
#  "Ebony's",
#  "ebony's",
#  "Urbain's",
#  "Urbano's",
#  "Urban's",
#  'Urbanus',
#  "Urbanus's",
#  "Ebeneezer's",
#  "Ebeneser's",
#  "Ebenezer's",
#  'urbanest',
#  'abound',
#  'urbanity',
#  'abandon',
#  'abounding',
#  'abandonment',
#  "abandonment's",
#  'abandoning',
#  'abandons',
#  'abundance',
#  "abundance's",
#  'abundances',
#  'abandoned',
#  'abundant',
#  'abundantly',
#  'abounds',
#  "urbanity's",
#  'abounded',
#  'ibuprofen',
#  'abbr',
#  'Abra',
#  'Aubree',
#  'Aubrey',
#  'Aubrie',
#  'Aubry',
#  'Ebro',
#  'Iberia',
#  'abbrev',
#  'abbrevs',
#  'abbreviate',
#  'abbreviating',
#  'abbreviates',
#  'abbreviated',
#  'abbreviation',
#  "abbreviation's",
#  'abbreviations',
#  'Abraham',
#  'Ibrahim',
#  "Abraham's",
#  "Ibrahim's",
#  'Abrahan',
#  "Abrahan's",
#  'abridge',
#  'Aborigine',
#  'aborigine',
#  'aboriginal',
#  'aboriginals',
#  "Aborigine's",
#  'Aborigines',
#  "aborigine's",
#  'aborigines',
#  'abridges',
#  'abridged',
#  'abrogate',
#  'abrogator',
#  'abracadabra',
#  'abrogating',
#  'abrogates',
#  "abrogator's",
#  'abrogators',
#  'abrogated',
#  'abrogation',
#  "abrogation's",
#  'abrogations',
#  'arboreal',
#  'Abram',
#  'Abramo',
#  "Abramo's",
#  "Abram's",
#  'Abrams',
#  'Abran',
#  'Auberon',
#  'Iberian',
#  'Oberon',
#  "O'Brien",
#  "Abran's",
#  "Auberon's",
#  "Iberian's",
#  'Iberians',
#  "Oberon's",
#  'aberrant',
#  'abrupt',
#  'abrupter',
#  'abruptly',
#  'abruptness',
#  "abruptness's",
#  'abruptest',
#  "Abra's",
#  "Aubree's",
#  "Aubrey's",
#  "Aubrie's",
#  "Aubry's",
#  "Ebro's",
#  "Iberia's",
#  'abrasive',
#  'abrasively',
#  'abrasiveness',
#  "abrasive's",
#  'abrasives',
#  'abreast',
#  'abrade',
#  'abroad',
#  'Aubrette',
#  'abridging',
#  'arboretum',
#  "arboretum's",
#  'arboretums',
#  'abrading',
#  'abrades',
#  "Aubrette's",
#  'abraded',
#  'airbrush',
#  'aberration',
#  'abrasion',
#  'airbrushing',
#  'aberrational',
#  "aberration's",
#  'aberrations',
#  "abrasion's",
#  'abrasions',
#  'airbrushes',
#  "airbrush's",
#  'airbrushed',
#  'abase',
#  "Abba's",
#  'Abbas',
#  "Abbe's",
#  'abbess',
#  "abbess's",
#  "Abbey's",
#  "abbey's",
#  'abbeys',
#  "Abbie's",
#  "Abbi's",
#  "Abby's",
#  "Abe's",
#  "Abeu's",
#  "Abey's",
#  "Abie's",
#  'ABS',
#  "Ab's",
#  'abs',
#  "abs's",
#  'abuse',
#  'abuser',
#  'abuzz',
#  'abyss',
#  "abyss's",
#  'airbase',
#  'airbus',
#  "airbus's",
#  "Aube's",
#  "Eba's",
#  "eBay's",
#  "Ebba's",
#  'ebbs',
#  "Eb's",
#  "Ibbie's",
#  "Ibby's",
#  'ibis',
#  "ibis's",
#  'Ibiza',
#  "Ibo's",
#  'obese',
#  'obeys',
#  "Obie's",
#  "obi's",
#  'obis',
#  "oboe's",
#  'oboes',
#  "Ob's",
#  'obs',
#  "Oby's",
#  "orb's",
#  'orbs',
#  'absorb',
#  'absorber',
#  'absorbing',
#  'absorbingly',
#  'absorbency',
#  "absorbency's",
#  'absorbent',
#  'absorbents',
#  "absorber's",
#  'absorbers',
#  'absorbs',
#  'absorbed',
#  'abusive',
#  'observe',
#  'observer',
#  'observable',
#  'observably',
#  'observables',
#  'observability',
#  "observability's",
#  'abusively',
#  'observing',
#  'abusiveness',
#  "abusiveness's",
#  'observance',
#  "observance's",
#  'observances',
#  'observant',
#  'observantly',
#  "observer's",
#  'observers',
#  'observes',
#  'observed',
#  'observatory',
#  'observatories',
#  "observatory's",
#  'observation',
#  'observational',
#  'observationally',
#  "observation's",
#  'observations',
#  'obsequy',
#  'abscond',
#  'absconder',
#  'absconding',
#  "absconder's",
#  'absconders',
#  'absconds',
#  'absconded',
#  'obscure',
#  'obscurer',
#  'obscurely',
#  'obscurement',
#  'obscuring',
#  'obscureness',
#  "obscureness's",
#  'obscurantism',
#  "obscurantism's",
#  'obscurantist',
#  "obscurantist's",
#  'obscurantists',
#  'obscures',
#  'obscurest',
#  'obscured',
#  'obscurity',
#  'obscurities',
#  "obscurity's",
#  'obscuration',
#  'obsequies',
#  'obsequious',
#  'obsequiously',
#  'obsequiousness',
#  'abseil',
#  'abseiler',
#  'abyssal',
#  'absolve',
#  'absolving',
#  'absolves',
#  'absolved',
#  'Absalom',
#  "Absalom's",
#  'abseiling',
#  'abseils',
#  'obsolesce',
#  'obsolescing',
#  'obsolescence',
#  'obsolescent',
#  'obsolesces',
#  'obsolesced',
#  'abseiled',
#  'absolute',
#  'absoluter',
#  'obsolete',
#  'absolutely',
#  'obsoleting',
#  'absoluteness',
#  "absoluteness's",
#  'absolutes',
#  'obsoletes',
#  'absolutism',
#  "absolutism's",
#  'absolutest',
#  'absolutist',
#  "absolutist's",
#  'absolutists',
#  'obsoleted',
#  'absolution',
#  "absolution's",
#  'abysmal',
#  'abysmally',
#  'abasement',
#  'abasing',
#  'abusing',
#  'Abyssinia',
#  'Ibsen',
#  'obscene',
#  'obscener',
#  'Orbison',
#  'absinthe',
#  "absinthe's",
#  'obscenely',
#  'Abyssinian',
#  'absence',
#  "Abyssinia's",
#  "Ibsen's",
#  'obeisance',
#  "Orbison's",
#  "absence's",
#  'absences',
#  "obeisance's",
#  'obeisances',
#  'obscenest',
#  'absent',
#  'absentee',
#  'obeisant',
#  'obscenity',
#  'absently',
#  'absentminded',
#  'absentmindedly',
#  'absentmindedness',
#  'absenting',
#  "absentee's",
#  'absentees',
#  'absents',
#  'obscenities',
#  "obscenity's",
#  'absenteeism',
#  "absenteeism's",
#  'absented',
#  'absorptive',
#  'absorptivity',
#  "absorptivity's",
#  'absorption',
#  "absorption's",
#  'absorptions',
#  'abases',
#  ...]

# %% [markdown]
# ### Analysis of a Single Text

# %%
tmo = tqa.generate_metrics_obj('my personal number: 12.345.678-9 fsafdas')
tmo.quality_score
# Out:
# 2

# %%
tmo.total_words
# Out:
# 4

# %%
tmo.wrong_words
# Out:
# 1

# %% [markdown]
# ### Analysis of Multiple Text in DataFrame

# %%
s3 = boto3.client('s3')
comprehend_client = boto3.client('comprehend',region_name = AWS_REGION)

# %%
obj = s3.get_object(Bucket=bucket, Key=key2)
obj = BytesIO(obj['Body'].read())

df_example = pd.read_csv(obj, sep=",", error_bad_lines=False, warn_bad_lines=False, nrows=1000)
df_example.head(3)
# Out:
#    Ticket #                            Customer Complaint       Date  \
# 0    250635                 Comcast Cable Internet Speeds  4/22/2015
# 1    223441  Payment disappear - service got disconnected   4/8/2015
# 2    242732                             Speed and Service  4/18/2015
#
#           Time Received Via      City     State  Zip code  Status  \
# 0   3:53:50 PM     Internet  Abingdon  Maryland     21009  Closed
# 1  10:22:56 AM     Internet   Acworth   Georgia     30102  Closed
# 2   9:55:47 AM     Internet   Acworth   Georgia     30101  Closed
#
#   Filing on Behalf of Someone  \
# 0                          No
# 1                          No
# 2                         Yes
#
#                                          Description
# 0  I have been contacting Comcast Internet Techni...
# 1  Back in January 2015 I made 2 payments: One fo...
# 2  Our home is located at in Acworth Georgia 3010...

# %%
start_time = dt.now()

series_all_text = df_example["Customer Complaint"] + df_example["Description"]
series_text_metrics_results = series_all_text.apply(tqa.generate_metrics_obj)
print(f'Analysis ended ({dt.now() - start_time})')
checkpoint = dt.now()

df_example['Total Words'] = series_text_metrics_results.apply(lambda x: x.total_words)
print(f'Total Words column created ({dt.now() - checkpoint})')
checkpoint = dt.now()

df_example['Wrong Words'] = series_text_metrics_results.apply(lambda x: x.wrong_words)
print(f'Wrong Words column created ({dt.now() - checkpoint})')
checkpoint = dt.now()

df_example['Quality Score'] = series_text_metrics_results.apply(lambda x: x.quality_score)
print(f'Quality Score column created ({dt.now() - checkpoint})')

print(f'\nTotal execution time: {dt.now() - start_time}')
print(f'Data processed: {len(series_all_text)} texts')
# Out:
# Analysis ended (0:04:20.676670)
# Wrong Words column created (0:00:00.002620)
# Wrong Words column created (0:00:00.001329)
# Wrong Words column created (0:00:00.001313)
#
# Total execution time: 0:04:20.682360
# Data processed: 1000 texts

# %%
df_example.head(3)
# Out:
#    Ticket #                            Customer Complaint       Date  \
# 0    250635                 Comcast Cable Internet Speeds  4/22/2015
# 1    223441  Payment disappear - service got disconnected   4/8/2015
# 2    242732                             Speed and Service  4/18/2015
#
#           Time Received Via      City     State  Zip code  Status  \
# 0   3:53:50 PM     Internet  Abingdon  Maryland     21009  Closed
# 1  10:22:56 AM     Internet   Acworth   Georgia     30102  Closed
# 2   9:55:47 AM     Internet   Acworth   Georgia     30101  Closed
#
#   Filing on Behalf of Someone  \
# 0                          No
# 1                          No
# 2                         Yes
#
#                                          Description  Total Words  \
# 0  I have been contacting Comcast Internet Techni...          275
# 1  Back in January 2015 I made 2 payments: One fo...          231
# 2  Our home is located at in Acworth Georgia 3010...          491
#
#    Wrong Words  Quality Score
# 0           20             13
# 1           16             13
# 2           43             11

# %% [markdown]
# ## Results

# %% [markdown]
# ### Top 10 Quality Scored Texts

# %%
selected_columns = ['Customer Complaint', 'Description', 'Total Words', 'Wrong Words', 'Quality Score']
df_example[selected_columns].sort_values('Quality Score', ascending=False).head(10)
# Out:
#                                   Customer Complaint  \
# 859  Hang-ups, Lies, Bill more than 2x higher & more
# 92                            Unbelievable Treatment
# 4         Comcast not working and no service to boot
# 689                                  Comcast Service
# 964                       Customer Service Nightmare
# 928                             internet and service
# 283                             Unauthorized billing
# 209     Monthly Charges Increased without any notice
# 198                              Deceptive Practices
# 715                                   Comcast issues
#
#                                            Description  Total Words  \
# 859  I have been a loyal customer of Comcast. I had...         1094
# 92   I am getting overcharged with comcast / xfinit...          690
# 4    I have been a customer of Comcast of some sort...          652
# 689  Moved to a new address on 04/09/15 wherein I h...          388
# 964  I tried to setup cable at a new apartment.\n A...          214
# 928  I have been paying to get an internet speed of...         1258
# 283  I have been a Comcast customer for many years,...          541
# 209  I have signed a two years internet service pro...          211
# 198  I inadvertently git behind on my Internet bill...          161
# 715  i have been a customer for comcast for 15 mont...          185
#
#      Wrong Words  Quality Score
# 859           19             54
# 92            12             53
# 4             13             46
# 689            8             43
# 964            4             42
# 928           33             37
# 283           14             36
# 209            5             35
# 198            4             32
# 715            5             30
